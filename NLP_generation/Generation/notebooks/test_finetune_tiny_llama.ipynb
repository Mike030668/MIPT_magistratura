# %%
import numpy as np
import pandas as pd

# %%
# публичная ссылка на подготовленный ранее датасет, можно заменить на свою
url='https://drive.google.com/file/d/1qdvlHkSoAcxty-SG-CD26LeF5pDtk3BU/view?usp=drive_link'
file_id=url.split('/')[-2]
dwn_url='https://drive.google.com/uc?id=' + file_id

load_df = pd.read_pickle(dwn_url)
load_df.sample(10)
# Out:
#       Season Episode  speaker  \
# 16338      6      17     Kyle
# 911       11       2     Kyle
# 82        10       1     Kyle
# 16276      6      16  Butters
# 3441      13      14     Kyle
# 4878      15      13     Kyle
# 9292       2       9     Stan
# 12708      4      10     Stan
# 14499      6       1  Butters
# 6506      18       1  Cartman
#
#                                                    query  \
# 16338                                Jesus, behind you!
# 911                                                Dude!
# 82                                                CHEF!
# 16276                                            We are?
# 3441                                     Aaaaah! Gross!
# 4878                Dude, there's a guy with a gun here!
# 9292   Dude, how do you tell if a piece of poo is in ...
# 12708                     Confession box is over there!
# 14499                                         That's me!
# 6506   Well, I guess everything's out on the table no...
#
#                               companions  \
# 16338        [Kyle, Stan, Kyle, Cartman]
# 911       [Stan, Cartman, Kyle, Cartman]
# 82           [Stan, Kyle, Cartman, Stan]
# 16276       [Butters, Stan, Randy, Stan]
# 3441           [Kyle, Randy, Kyle, Stan]
# 4878            [Kyle, Stan, Kyle, Stan]
# 9292         [Stan, Kyle, Cartman, Kyle]
# 12708     [Stan, Cartman, Stan, Cartman]
# 14499        [Kyle, Stan, Butters, Stan]
# 6506   [Cartman, Stan, Cartman, Butters]
#
#                                              close_reply  \
# 16338  [You bastards. , Uh, on Steven, on Fluffy, on ...
# 911    [Dude, how is putting Butters' wiener in his m...
# 82     [Oh my God... They killed Chef., You bastards....
# 16276  [Oh, not really sir, I just uh..., Get the fuc...
# 3441   [Aw, sick! , You can't just leave my son in th...
# 4878   [Would you guys stop!, Aw, I think he's just k...
# 9292   [To the sewer, dude., Of course, the sewer! Th...
# 12708  [You're a sinner!, Oh, this guy is so gonna bu...
# 14499  [Aha, and I'll have the City Chicken., Oh, dud...
# 6506   [Stan? Do you think our name is stupid too?, I...
#
#                                            neutral_reply  \
# 16338  [Oh my God. The Iraqis killed Jesus., Oh God.,...
# 911    [I know I know, check it out, look.  I got his...
# 82     [Dad!, I'm dying of boredom., Hey Eric, I'm ju...
# 16276  [Our parents are never gonna admit what they d...
# 3441   [Aaaah!  Oh my God, they killed Kenny!, Oh my ...
# 4878   [I'm just saying there's lots of symbols and s...
# 9292   [Where did everybody go?, Where does that gril...
# 12708  [Dad!, I'm dying of boredom., Hey Eric, I'm ju...
# 14499  [Uh, yes, we'd like one order of the City Beef...
# 6506   [Yeah. I guess... I guess everything is., Yeah...
#
#                                                bad_reply  \
# 16338  [You're gonna be eating those words, asshole.,...
# 911    [Dude, I don't think this is very sturdy. , I ...
# 82     [Aren't you Jewish, Kyle?, Well, Kyle, maybe I...
# 16276  [Well it's not where I aimed, honest., The kin...
# 3441   [Oh cool, Legos. Thanks, Butters., Hey! Let's ...
# 4878   [If you guys want there to be a Christmas, you...
# 9292   [Dude, did you just say "a-ight"?, Yeah, I bou...
# 12708  [Yeah, I think so., Put your office right here...
# 14499  [Come on guys. If we all help out, we can do i...
# 6506   [No, dickhole. Four tickets, 28th row, for the...
#
#                                                  context
# 16338  We don't know. They lost all contact with him....
# 911    But, uh-ih-it's only 6:30.. You guys! I got it...
# 82     Chef, we love you.. No! Chef, they've filled y...
# 16276  Oh, Stan!. Butters, we've go-! Oh, God, it sme...
# 3441   You guys! You guys have to do something to sto...
# 4878   Wow, check it out dude, we're on TV. . Ack dud...
# 9292   Yeah, I love these Salty Chocolate Balls, Chef...
# 12708  Come on, hurry up! . Oh no! It's locked!. What...
# 14499  Yeah. Boy, you fellas are sure gonna rip on me...
# 6506   Well, what are you gonna do? Go back to school...

# %%
# !pip install trl transformers accelerate git+https://github.com/huggingface/peft.git -Uqqq
# !pip install bitsandbytes einops wandb -Uqqq
#!pip install datasets -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 24.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 27.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 33.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 11.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 17.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.2 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 86.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 21.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 kB 32.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.6 MB/s eta 0:00:00

# %%
import torch
import glob
import pandas as pd
import numpy as np
import re
from peft import get_peft_model, PeftConfig, PeftModel, LoraConfig, prepare_model_for_kbit_training
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, TrainingArguments, GenerationConfig
from trl import SFTTrainer
from datasets import Dataset
import warnings
import random
warnings.filterwarnings("ignore")

# %%
# You will need to create a Hugging Face account if you do not have one,
# and then generate a write token to enter in the widget below
#from huggingface_hub import notebook_login
#notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
dir = "/content/drive/Othercomputers/My_comp/Документы/МФТИ_Наука_о_данных/NLP_generation/DZ/DZ_2/Project_gen_chatbot"
trained_model_dir = dir + '/tinyllama/checkpoint-600'

config = PeftConfig.from_pretrained(trained_model_dir)

# %%
# Loading the model with double quantization
model_name = "PY007/TinyLlama-1.1B-step-50K-105b"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
)


trained_model = AutoModelForCausalLM.from_pretrained(
	config.base_model_name_or_path,
	quantization_config=bnb_config,
	trust_remote_code=True,
	device_map='auto'

	)
# Out:
# config.json:   0%|          | 0.00/607 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.40G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/129 [00:00<?, ?B/s]

# %%
# Creating tokenizer and defining the pad token
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True, padding_side='right')
tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
# Generating lyrics with the base model. The repetition penalty in the generation config prevents the model from continually repeating the same string.
device = 'cuda' if torch.cuda.is_available() else 'cpu'
def generate_answer(query, model):
    encoding = tokenizer(query, return_tensors="pt").to(device)
    generation_config = GenerationConfig(max_new_tokens=250, pad_token_id = tokenizer.eos_token_id,repetition_penalty=1.3, eos_token_id = tokenizer.eos_token_id)
    outputs = model.generate(input_ids=encoding.input_ids, generation_config=generation_config)
    text_output = tokenizer.decode(outputs[0],skip_special_tokens=True)
    return text_output.split("[/INST]")[1].split("\n\n")[0]

def get_test_prompt(df):
    use_col = ['speaker', 'query', 'context', "companions", "close_reply"]
    j = random.randint(0, df.shape[0])
    id = random.randint(0, len(df[use_col].iloc[j]["companions"]))
    query = df[use_col].iloc[j]['query']
    role = df[use_col].iloc[j]['companions'][id]
    context = df[use_col].iloc[j]['context']
    reply = df.iloc[j][use_col]["close_reply"][id]
    prompt = f"<s>[INST]"
    prompt += f'Use the given context to guide your an about the query like indicated in your role'
    prompt += f"query: {query}\n\n"
    prompt += f"context: {context}\n\n"
    prompt += f"your role: {role}\n\n"
    prompt += f'answer:[/INST]</s>'

    return query, role, reply, prompt

# %%
query, role, reply, prompt = get_test_prompt(load_df)
answer = generate_answer(prompt, trained_model)

print(f"\n\nQuery: {query}\n")
print(f"Trained_model reply with role: {role}\n")

print(answer)
print()
print(f'Answer in df: {reply}')
# Out:
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Query: Uh excuse me, Token already has representation.
#
# Trained_model reply with role: Stan
#
#  a token for 20 bucks? Yes, I can afford it.
#
# Answer in df: So unfair... so unfair.

# %%
query, role, reply, prompt = get_test_prompt(load_df)
answer = generate_answer(prompt, trained_model)

print(f"\n\nQuery: {query}\n")
print(f"Trained_model reply with role: {role}\n")

print(answer)
print()
print(f'Answer in df: {reply}')
# Out:
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Query: It's all right. Let's go straight. Now turn left. Okay, now go about ten steps.
#
# Trained_model reply with role: Randy
#
#  you can do it. And then we will be able to use this as our own personalized monsters. So let's go straight. Now turn left. Okay, now go about ten steps.
#
# Answer in df: Arrrg!  Hey, what are you doing?!

# %%
query, role, reply, prompt = get_test_prompt(load_df)
answer = generate_answer(prompt, trained_model)

print(f"\n\nQuery: {query}\n")
print(f"Trained_model reply with role: {role}\n")

print(answer)
print()
print(f'Answer in df: {reply}')
# Out:
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Query: What?! Get the hell out of here!
#
# Trained_model reply with role: Cartman
#
# , but hey, let me get this straight. You have no idea what you've gotten yourself into. It was just some random guy with a cart and a bunch of cats. And now you're going to tell us how much funny stuff you think we should all do together? That's right, you know, because if you don't believe me, then go ahead and try to convince someone else. But seriously, why would anyone ever need to hear anything from you? Just sit back down and shut up.
#
# Answer in df: What? Tell us?

# %%
query, role, reply, prompt = get_test_prompt(load_df)
answer = generate_answer(prompt, trained_model)

print(f"\n\nQuery: {query}\n")
print(f"Trained_model reply with role: {role}\n")

print(answer)
print()
print(f'Answer in df: {reply}')
# Out:
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Query: We did!
#
# Trained_model reply with role: Cartman
#
# . You can use this as a way to help people escape from that place!. I don't know how you do it but we have some things here!. And if you want to go back into the cave then just say 'I am going to die'. It will give you a chance to save yourself!. If you are stuck inside the cave for any reason then just ask someone else to come rescue you!. They might not understand what is happening!. So you need to tell them where you are coming from!. Then they would take care of you!. Or maybe you could try to run away with them!. The only problem is that you won't be able to see anyone anymore!. There was one person left behind!. She had been dead since she died!. She didn't even look at me!. She looked so sad!. She said something like "You were my friend".!. What does he mean?. She told him that her name was <NAME>.!. She also gave us a piece of paper saying that she wanted to leave us alone!. She asked us to stay together!. We agreed!. Afterwards, we went on our adventure!. We found a lot of treasures!. Someone helped us!. We made friends!. We started talking
#
# Answer in df: Ah ah ah, ah, I know what you're thinking, Stan. You're thinking, you're gonna go tell Kyle. Look, I know you think he's your best friend, but Kyle is a Jew rat! He has his Jew ethics while he hoards his greedy Jew gold, and he will Jew you out if you tell him about this!
