# %% [markdown]
# #**ДИСКРИМИНАНТНЫЙ АНАЛИЗ С ИСПОЛЬЗОВАНИЕМ**
#
# **КОНЦЕПЦИИ НЕЧЕТКИХ МНОЖЕСТВ...**

# %% [markdown]
#     Студент: Пузицкий Михаил Леонидович
#     Группа: М08-200НД

# %% [markdown]
# Ответы на вопросы [по статье](https://www.academia.edu/10988749/%D0%91%D0%BE%D1%80%D0%BE%D0%B4%D0%BA%D0%B8%D0%BD_%D0%9B_%D0%98_%D0%94%D0%B8%D1%81%D0%BA%D1%80%D0%B8%D0%BC%D0%B8%D0%BD%D0%B0%D0%BD%D1%82%D0%BD%D1%8B%D0%B9_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7_%D1%81_%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%D0%BC_%D0%BA%D0%BE%D0%BD%D1%86%D0%B5%D0%BF%D1%86%D0%B8%D0%B8_%D0%BD%D0%B5%D1%87%D0%B5%D1%82%D0%BA%D0%B8%D1%85_%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2_%D0%B2_%D0%B7%D0%B0%D0%B4%D0%B0%D1%87%D0%B5_%D0%BE%D1%86%D0%B5%D0%BD%D0%BA%D0%B8_%D0%B4%D0%B2%D1%83%D1%85_%D0%BF%D1%83%D1%82%D0%B5%D0%B9_%D0%B0%D0%B3%D1%80%D0%B0%D1%80%D0%BD%D0%BE%D0%B9_%D1%8D%D0%B2%D0%BE%D0%BB%D1%8E%D1%86%D0%B8%D0%B8_%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B8_%D0%BD%D0%B0_%D1%80%D1%83%D0%B1%D0%B5%D0%B6%D0%B5_XIX_XX_%D0%B2%D0%B2_%D0%98%D1%81%D1%82%D0%BE%D1%80%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D0%B8%D0%BD%D1%84%D0%BE%D1%80%D0%BC%D0%B0%D1%82%D0%B8%D0%BA%D0%B0_2013_3_%D0%A1_30_38)
#
# Дискриминантный анализ с использованием концепции нечетких
# множеств в задаче оценки двух путей аграрной эволюции России на рубеже XIX–XX вв
#
#     Бородкина Леонида Иосифовича
#     Доктор исторических наук, профессор, заведующий кафедрой исторической информатики
#     исторического факультета МГУ имени М. В. Ломоносова
#     E-mail: borodkin@hist.msu.ru

# %% [markdown]
# # Задание 1. Ознакомиться с презентациями:
# - https://ppt-online.org/103524
#
# - http://www.myshared.ru/slide/534083/
#
# Сделано

# %% [markdown]
# #Задание 2. Прочитать статью (есть в сети):
# Бородкин Л.И. Дискриминантный анализ с использованием концепции нечетких
# множеств в задаче оценки двух путей аграрной эволюции России на рубеже XIX–XX вв. //
# Историческая информатика. 2013. № 3. С. 30-38.
# **Ответить на вопросы:**

# %% [markdown]
# ## а) Какая оптимизационная задача решается в этой работе?

# %% [markdown]
# ### Ответ
#
# В статье решается задача построения типологии аграрного развития губерний России на рубеже XIX–XX вв на основе  алгоритмы кластер-анализа (автоматической классификации
# и классификации с использованием обучающей выборки), основанные на использовании теории нечетких множеств.  Попытки «жесткого» определения понятия «тип» в историко-типологическом исследовании нередко входят в противоречие с принципиальной «размытостью» границ между типами. Это обстоятельство и приводит к использованию концепций теории нечетких множеств в типологических задачах экономической истории.

# %% [markdown]
# ## б) Введите порог для определения ядра каждого из двух нечетких классов и укажите,
# какие объекты (губернии) вошли в состав ядра 1-го и 2-го классов.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Данные взятые из таблицы статьи

# %%
txt = """
Архангельская
Астраханская
Бессарабская
Виленская
Витебская
Владимирская
Вологодская
Волынская
Воронежская
Вятская 
Гродненская
Донская
Екатеринославская 
Казанская 
Калужская 
Киевская 
Ковенская 
Костромская 
Курляндская 
Курская 
Лифляндская 
Минская 
Могилевская 
Московская 
Новгородская 
Нижегородская 
Олонецкая
Оренбургская 
Орловская
Пензенская
Пермская
Петербургская
Подольская
Полтавская 
Псковская
Рязанская
Самарская
Саратовская 
Симбирская
Смоленская
Таврическая 
Тамбовская 
Тверская 
Тульская 
Уфимская 
Харьковская
Херсонская 
Черниговская 
Эстляндская 
Ярославская
"""

# %%
gub = txt.split('\n')[1:-1]
len(gub)
# Out:
# 50

# %%
x = [1., 0.84, 0.42, 0, 0.06, 0.92, 0.71, 0.01, 0.65, 0.68, 0., 1., 1.,
     0.52, 0.73, 0.15, 0.23, 0.68, 0.21, 0.59, 0.03, 0., 0.11, 0.88, 0.52,
     0.54, 0.96, 0.83, 0.38, 0.35, 0.37, 0.42, 0., 0.38, 0.41, 0.7, 0.79,
     0.6, 0.44, 0.4, 1., 0.52, 0.71, 0.51, 0.50, 0.62, 0.84, 0.37, 0., 0.82]

y = [0., 0.16, 0.58, 1., 0.94, 0.08, 0.29, 0.99, 0.35, 0.32, 1., 0., 0.,
     0.48, 0.27, 0.85, 0.77, 0.32, 0.79, 0.41, 0.97, 1., 0.89, 0.12, 0.48,
     0.46, 0.04, 0.17, 0.62, 0.65, 0.63, 0.58, 1., 0.62, 0.58, 0.3, 0.21, 0.4, 
     0.56, 0.60, 0, 0.48, 0.29, 0.49, 0.50, 0.38, 0.16, 0.63, 1., 0.18]

z = [-53.46, -37.55, 16.21, 15.48, 2.47, -42.04, -31.24, 5.05, -27.94,
     -29.69, 11.71, -66.53, -50.91, -21.19, -32.09, -0.8, -6.09, -29.32,
     -4.99, -24.76, 4.38, 20.55, 0.28, -39.61, -21.07, -22.23, -44.14, -37.32, 
     -13.83, -12.28, -13.47, -16.15, 13.17, -13.88, -15.68, -30.40, -35.32, -25.17,
     -17.02, -15.17, -46.41, -21.11, -31.18, -20.53, -19.98, -26.15, -37.63, -13.13, 27., -36.97]
     
x = np.array(x)
y = np.array(y)
z = np.array(z)
labels= np.arange(len(x))
len(labels)
# Out:
# 50

# %% [markdown]
# ### В плоскости

# %%
fig, ax = plt.subplots(1, 3, sharex=True, figsize = (20,6))
ax[0].scatter(z, x, c='r')# , label = 'Nifty 50 Buyand Hold')
ax[1].scatter(z, y)# label = 'Strategy')
ax[0].set(title = 'Фермерсий тип', ylabel = 'Отношение к Фермерсому типу')
ax[1].set(title = 'Юнкерский тип', ylabel = 'Отношение к Юнкерскому типу')
ax[2].set(title = 'Оба типа', ylabel = 'Отношение к типу')

ax[2].scatter(z, x, c='r')# , label = 'Nifty 50 Buyand Hold')
ax[2].scatter(z, y)# label = 'Strategy')
ax[0].grid(True)
ax[1].grid(True)
ax[2].grid(True)

# %% [markdown]
# ### В 3D построении

# %%
fig = plt.figure(figsize=(20, 15))
ax = fig.add_subplot(projection='3d')

color_map = plt.get_cmap('spring')
scatter_plot = ax.scatter(x, y, z, c= labels,  cmap = color_map)
for i in labels: 
    ax.text(x[i], y[i], z[i],  '%s' % (str(i)), size=12, zorder=1,  
    color='k') 

ax.text(x[2]+.05, y[2]+.05, z[2], '%s' % (f'Выброс - {gub[2]}'), size=15, zorder=1,  color='b')

ax.scatter(0.5, 0.5, -19.8, c='y', marker = 'o', s=100)
ax.text(0.55, 0.55, -19.8, '%s' % ('Уфимская'), size=15, zorder=1,  color='y')
ax.scatter(0, 1, 5.8, c='r', marker = 'v', s=100)
ax.text(0.05, 1.05,  5.8, '%s' % ('Центр масс 2-го класса'), size=15, zorder=1,  color='r')
ax.scatter(1, 0, -46.05, c='g', marker = 'v', s=100)
ax.text(1.05, .05,  -46.05, '%s' % ('Центр масс 1-го класса'), size=15, zorder=1,  color='g')

plt.colorbar(scatter_plot)

ax.set_xlabel('Фермерсий тиа')
ax.set_ylabel('Юнкерский тип')
ax.set_zlabel('F(x)')

plt.show()

# %% [markdown]
# Есть выброс явный у Бессарабской губернии, данные перепроверил.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# В районе координаты центров классов на дискриминантной оси  5.80 (для помещичьего типа) и –46,05 (для крестьянского типа) у нас происходит переход к весу 1 в отношении к определенному классу

# %%
ind_1 = np.where(x>.99)[0]
ind_2 = np.where(y>.99)[0]

print(f'Ядро первого класса:')
for i in ind_1:
  print(f'губерния - {gub[i]}')
print()
print(f'Ядро второго класса:')
for i in ind_2:
  print(f'губерния - {gub[i]}')
# Out:
# Ядро первого класса:
# губерния - Архангельская
# губерния - Донская
# губерния - Екатеринославская
# губерния - Таврическая
#
# Ядро второго класса:
# губерния - Виленская
# губерния - Гродненская
# губерния - Минская
# губерния - Подольская
# губерния - Эстляндская

# %% [markdown]
# ### Ответ:
#
# В районе координаты центров классов на дискриминантной оси `5.80` (для помещичьего типа) и `–46,05` (для крестьянского типа) происходит переход к весу 1 в отношении определенного класса. Но Бессарабская выпадает из этой посследовательности.
#
# Порогом будет:
#
# *Крестьянского типа ядро (1 : 0):*
#
#     губерния - Архангельская
#     губерния - Донская
#     губерния - Екатеринославская
#     губерния - Таврическая
#
#
# *Помещечьего типа ядро (0 : 1):*
#
#     губерния - Виленская
#     губерния - Гродненская
#     губерния - Минская
#     губерния - Подольская
#     губерния - Эстляндская
